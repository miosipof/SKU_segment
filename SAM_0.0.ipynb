# %%
import os
import torch
import json
import pandas as pd
from IPython.display import Image, clear_output

# %%
print(f"Setup complete. Using torch {torch.__version__} " \
      f"({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 2.6.0+cu124 (NVIDIA GeForce RTX 3090)

# %%
ds_path = "/SKU110K_fixed/"

# %%
# annotations = pd.read_csv("/SKU110K_fixed/annotations/annotations_test.csv")
# annotations.columns=['image_name','x1','y1','x2','y2','class','image_width','image_height']
# annotations.head(5)
# Out:
#    image_name    x1    y1    x2    y2   class  image_width  image_height
# 0  test_0.jpg   727  2269   862  2376  object         2448          3264
# 1  test_0.jpg   463  2274   715  2434  object         2448          3264
# 2  test_0.jpg   158  2290   283  2444  object         2448          3264
# 3  test_0.jpg     0  2290   154  2456  object         2448          3264
# 4  test_0.jpg  1995  2032  2131  2199  object         2448          3264

# %%
raw_data = {
    'train': None,
    'val': None,
    'test': None
}

for split in raw_data.keys():
    annotations = pd.read_csv(f"/SKU110K_fixed/annotations/annotations_{split}.csv")
    annotations.columns=['image_name','x1','y1','x2','y2','class','image_width','image_height']
    raw_data[split] = annotations
    print(f"{split} split: {len(annotations)} annotations, {len(annotations.groupby('image_name'))} samples")
# Out:
# train split: 1208481 annotations, 8219 samples
# val split: 90967 annotations, 588 samples
# test split: 431545 annotations, 2936 samples

# %%
ds = {}

for split, data in raw_data.items():
    
    data = data.reset_index()
    images = set(data['image_name'])

    ds[split] = []

    for i, image_name in enumerate(list(images)):
        df = data[data['image_name'] == image_name]

        img_path = os.path.join(ds_path,image_name)
        bboxes = []

        for idx, ann in df.iterrows():
            bbox = [ann['x1'],ann['x2'],ann['y1'],ann['y2']]
            bboxes.append(bbox)        

        ds[split].append({"image_path": img_path, "bboxes": bboxes})
        if i%50 == 0:
            print(f"{100*i/len(images):.1f}% of {split} split processed")


with open('sku110_dataset.json', 'w') as f: 
    json.dump(ds, f)
# Out:
# 0.0% of train split processed
# 0.6% of train split processed
# 1.2% of train split processed
# 1.8% of train split processed
# 2.4% of train split processed
# 3.0% of train split processed
# 3.7% of train split processed
# 4.3% of train split processed
# 4.9% of train split processed
# 5.5% of train split processed
# 6.1% of train split processed
# 6.7% of train split processed
# 7.3% of train split processed
# 7.9% of train split processed
# 8.5% of train split processed
# 9.1% of train split processed
# 9.7% of train split processed
# 10.3% of train split processed
# 11.0% of train split processed
# 11.6% of train split processed
# 12.2% of train split processed
# 12.8% of train split processed
# 13.4% of train split processed
# 14.0% of train split processed
# 14.6% of train split processed
# 15.2% of train split processed
# 15.8% of train split processed
# 16.4% of train split processed
# 17.0% of train split processed
# 17.6% of train split processed
# 18.3% of train split processed
# 18.9% of train split processed
# 19.5% of train split processed
# 20.1% of train split processed
# 20.7% of train split processed
# 21.3% of train split processed
# 21.9% of train split processed
# 22.5% of train split processed
# 23.1% of train split processed
# 23.7% of train split processed
# 24.3% of train split processed
# 24.9% of train split processed
# 25.6% of train split processed
# 26.2% of train split processed
# 26.8% of train split processed
# 27.4% of train split processed
# 28.0% of train split processed
# 28.6% of train split processed
# 29.2% of train split processed
# 29.8% of train split processed
# 30.4% of train split processed
# 31.0% of train split processed
# 31.6% of train split processed
# 32.2% of train split processed
# 32.9% of train split processed
# 33.5% of train split processed
# 34.1% of train split processed
# 34.7% of train split processed
# 35.3% of train split processed
# 35.9% of train split processed
# 36.5% of train split processed
# 37.1% of train split processed
# 37.7% of train split processed
# 38.3% of train split processed
# 38.9% of train split processed
# 39.5% of train split processed
# 40.2% of train split processed
# 40.8% of train split processed
# 41.4% of train split processed
# 42.0% of train split processed
# 42.6% of train split processed
# 43.2% of train split processed
# 43.8% of train split processed
# 44.4% of train split processed
# 45.0% of train split processed
# 45.6% of train split processed
# 46.2% of train split processed
# 46.8% of train split processed
# 47.5% of train split processed
# 48.1% of train split processed
# 48.7% of train split processed
# 49.3% of train split processed
# 49.9% of train split processed
# 50.5% of train split processed
# 51.1% of train split processed
# 51.7% of train split processed
# 52.3% of train split processed
# 52.9% of train split processed
# 53.5% of train split processed
# 54.1% of train split processed
# 54.8% of train split processed
# 55.4% of train split processed
# 56.0% of train split processed
# 56.6% of train split processed
# 57.2% of train split processed
# 57.8% of train split processed
# 58.4% of train split processed
# 59.0% of train split processed
# 59.6% of train split processed
# 60.2% of train split processed
# 60.8% of train split processed
# 61.4% of train split processed
# 62.1% of train split processed
# 62.7% of train split processed
# 63.3% of train split processed
# 63.9% of train split processed
# 64.5% of train split processed
# 65.1% of train split processed
# 65.7% of train split processed
# 66.3% of train split processed
# 66.9% of train split processed
# 67.5% of train split processed
# 68.1% of train split processed
# 68.7% of train split processed
# 69.4% of train split processed
# 70.0% of train split processed
# 70.6% of train split processed
# 71.2% of train split processed
# 71.8% of train split processed
# 72.4% of train split processed
# 73.0% of train split processed
# 73.6% of train split processed
# 74.2% of train split processed
# 74.8% of train split processed
# 75.4% of train split processed
# 76.0% of train split processed
# 76.7% of train split processed
# 77.3% of train split processed
# 77.9% of train split processed
# 78.5% of train split processed
# 79.1% of train split processed
# 79.7% of train split processed
# 80.3% of train split processed
# 80.9% of train split processed
# 81.5% of train split processed
# 82.1% of train split processed
# 82.7% of train split processed
# 83.3% of train split processed
# 84.0% of train split processed
# 84.6% of train split processed
# 85.2% of train split processed
# 85.8% of train split processed
# 86.4% of train split processed
# 87.0% of train split processed
# 87.6% of train split processed
# 88.2% of train split processed
# 88.8% of train split processed
# 89.4% of train split processed
# 90.0% of train split processed
# 90.6% of train split processed
# 91.3% of train split processed
# 91.9% of train split processed
# 92.5% of train split processed
# 93.1% of train split processed
# 93.7% of train split processed
# 94.3% of train split processed
# 94.9% of train split processed
# 95.5% of train split processed
# 96.1% of train split processed
# 96.7% of train split processed
# 97.3% of train split processed
# 97.9% of train split processed
# 98.6% of train split processed
# 99.2% of train split processed
# 99.8% of train split processed
# 0.0% of val split processed
# 8.5% of val split processed
# 17.0% of val split processed
# 25.5% of val split processed
# 34.0% of val split processed
# 42.5% of val split processed
# 51.0% of val split processed
# 59.5% of val split processed
# 68.0% of val split processed
# 76.5% of val split processed
# 85.0% of val split processed
# 93.5% of val split processed
# 0.0% of test split processed
# 1.7% of test split processed
# 3.4% of test split processed
# 5.1% of test split processed
# 6.8% of test split processed
# 8.5% of test split processed
# 10.2% of test split processed
# 11.9% of test split processed
# 13.6% of test split processed
# 15.3% of test split processed
# 17.0% of test split processed
# 18.7% of test split processed
# 20.4% of test split processed
# 22.1% of test split processed
# 23.8% of test split processed
# 25.5% of test split processed
# 27.2% of test split processed
# 29.0% of test split processed
# 30.7% of test split processed
# 32.4% of test split processed
# 34.1% of test split processed
# 35.8% of test split processed
# 37.5% of test split processed
# 39.2% of test split processed
# 40.9% of test split processed
# 42.6% of test split processed
# 44.3% of test split processed
# 46.0% of test split processed
# 47.7% of test split processed
# 49.4% of test split processed
# 51.1% of test split processed
# 52.8% of test split processed
# 54.5% of test split processed
# 56.2% of test split processed
# 57.9% of test split processed
# 59.6% of test split processed
# 61.3% of test split processed
# 63.0% of test split processed
# 64.7% of test split processed
# 66.4% of test split processed
# 68.1% of test split processed
# 69.8% of test split processed
# 71.5% of test split processed
# 73.2% of test split processed
# 74.9% of test split processed
# 76.6% of test split processed
# 78.3% of test split processed
# 80.0% of test split processed
# 81.7% of test split processed
# 83.4% of test split processed
# 85.1% of test split processed
# 86.9% of test split processed
# 88.6% of test split processed
# 90.3% of test split processed
# 92.0% of test split processed
# 93.7% of test split processed
# 95.4% of test split processed
# 97.1% of test split processed
# 98.8% of test split processed

# %%
len(ds['train'])
# Out:
# 8219

# %%
def generate_mask_from_box(image, bbox, grabcut_iter=5):
    """
    Given a single bounding box [x1, y1, x2, y2] and an image (H x W x 3),
    return a binary mask (H x W) indicating the object's region.
    
    We use GrabCut initialized by a rectangle around the bounding box.
    This is a naive example of turning a box into a (rough) segmentation mask.
    """
    x1, y1, x2, y2 = bbox
    
    # Ensure coordinates are within image bounds
    h, w = image.shape[:2]
    x1 = max(0, min(x1, w - 1))
    x2 = max(0, min(x2, w - 1))
    y1 = max(0, min(y1, h - 1))
    y2 = max(0, min(y2, h - 1))
    
    # Create initial mask for GrabCut
    # Possible values in 'mask':
    #    cv2.GC_BGD    = 0 (definite background)
    #    cv2.GC_FGD    = 1 (definite foreground)
    #    cv2.GC_PR_BGD = 2 (probable background)
    #    cv2.GC_PR_FGD = 3 (probable foreground)
    mask = np.zeros((h, w), np.uint8)
    
    # GrabCut requires 2 background/foreground models
    bgd_model = np.zeros((1, 65), np.float64)
    fgd_model = np.zeros((1, 65), np.float64)

    # Rectangle for the bounding box
    rect = (x1, y1, x2 - x1, y2 - y1)
    
    # Initialize GrabCut with the bounding box
    cv2.grabCut(
        image,        # input image
        mask,         # mask to be modified
        rect,         # rectangle that includes the foreground object
        bgd_model,    # temporary array for background model
        fgd_model,    # temporary array for foreground model
        grabcut_iter, # number of iterations
        mode=cv2.GC_INIT_WITH_RECT
    )
    
    # After GrabCut, mask is in {0,1,2,3}, so let's create a binary mask
    # "where definite foreground OR probable foreground => object"
    bin_mask = np.where(
        (mask == cv2.GC_FGD) | (mask == cv2.GC_PR_FGD), 
        255, 
        0
    ).astype('uint8')
    
    return bin_mask

# %%
def box2mask_synthetic(annotations, output_dir='synthetic_masks'):
    """
    Loop over images & bounding boxes, produce synthetic masks, and save them.
    Each bounding box yields one mask image (with the same resolution).
    
    :param annotations: list of dicts
                       [ { 'image_path': ..., 'bboxes': [[x1,y1,x2,y2], ...] }, ...]
    :param output_dir: Where to store the mask images
    """
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    for ann_idx, ann in enumerate(annotations):
        image_path = ann['image_path']
        bboxes = ann['bboxes']
        
        # Read image
        image = cv2.imread(image_path)
        if image is None:
            print(f"Warning: Could not read image {image_path}. Skipping.")
            continue
        
        base_name = os.path.splitext(os.path.basename(image_path))[0]
        
        # For each bounding box, generate a mask
        for i, bbox in enumerate(bboxes):
            mask = generate_mask_from_box(image, bbox)
            
            # Save the mask as a PNG (or any format)
            mask_filename = f"{base_name}_box{i}.png"
            output_path = os.path.join(output_dir, mask_filename)
            cv2.imwrite(output_path, mask)
            
        print(f"Processed {len(bboxes)} boxes for {image_path} => masks saved to {output_dir}/")

# %%
box2mask_synthetic(annotations, output_dir=os.path.join(ds_path, 'synthetic_masks_output'))
